# %% [markdown]
# <div style="border:solid Chocolate 2px; padding: 40px">
#
# Дмитрий, привет, меня зовут Станислав, и я буду проверять твой проект. Предлагаю общаться на «ты», но если это неудобно - дай знать, и мы перейдем на «вы».
# Это учебный проект и здесь не стоит бояться делать ошибки, я хочу поделиться своим опытом и помочь тебе стать аналитиком данных.
# Уже выполнена большая работа над проектом, давай сделаем его еще лучше. Ниже ты найдешь мои комментарии - пожалуйста, не перемещай, не изменяй и не удаляй их. Я буду использовать цветовую разметку:
#
# <div class="alert alert-danger">
# <b>Комментарий с замечанием ревьюера:</b> Так выделены самые важные замечания. Как только ты их исправишь проект будет принят. </div>
#
# <div class="alert alert-warning">
# <b>Комментарий с небольшим замечанием или советом ревьюера:</b> Так выделены небольшие замечания или советы.
# </div>
#
# <div class="alert alert-success">
# <b>Комментарий с комплиментом ревьюера:</b> Так я выделяю все остальные комментарии.</div>
#
# Давай работать над проектом в диалоге: если ты что-то меняешь в проекте или отвечаешь на мои комментарии — пиши об этом.
# Мне будет легче отследить изменения, если ты выделишь свои комментарии:
# <div class="alert alert-info"> <b>Комментарий студента:</b> Например, вот так.</div>
#
# Всё это поможет выполнить повторную проверку твоего проекта оперативнее.
# </div>

# %% [markdown]
# <div style="border:solid Chocolate 2px; padding: 40px">
#
# # Общий вывод ревьюера
#
# <div class="alert alert-success">
#
# Проделана хорошая аналитическая работа. Код написан чисто, соблюдена структура проекта, графики оформлены корректно, отдельно отмечу, что написаны логичные и обоснованные выводы. Проект выполнен на хорошем аналитическом уровне, поэтому замечаний не много. Я отметил в проекте моменты, на которые необходимо обратить внимание, исправь их и проект будет принят.
# - по ссылкам ниже интересные материалы по А/В тестам
#
#
# https://habr.com/ru/company/avito/blog/571094/
#
# https://habr.com/ru/company/yandex/blog/476826/
#
# https://academy.yandex.ru/journal/kak-provesti-a-b-testirovanie-6-prostykh-shagov
#
# https://habr.com/ru/company/yandex/blog/342704/
#
# https://r-analytics.blogspot.com/2013/10/blog-post_13.html
#
# </div>
#
# <div class="alert alert-danger">
#
# - добавь, пожалуйста, формулировки гипотез
# </div>

# %% [markdown]
# <div class="alert alert-info"> <b>Комментарий студента:</b> Привет Станислав! Очень рад, что моя работа вызвала у вас положительные эмоции! Благодарю за оценку и ревью моего проекта! Отдельно спасибо за дополнительный материал для изучения по А/В тестам! </div>

# %% [markdown]
# <div style="border:solid Chocolate 2px; padding: 40px">
#
# # Общий вывод ревьюера в2
#
# <div class="alert alert-success">
#
# Отлично, замечания исправлены, работу принимаю и желаю успеха в следующих проектах.

# %% [markdown]
# # Проект: Принятие решений в бизнесе

# %% [markdown]
# ## Контекст

# %% [markdown]
# Вы — аналитик крупного интернет-магазина. Вместе с отделом маркетинга вы подготовили список гипотез для увеличения выручки.

# %% [markdown]
# ## Цель проекта

# %% [markdown]
# Приоритизируйте гипотезы, запустите A/B-тест и проанализируйте результаты.

# %% [markdown]
# ## Описание данных

# %% [markdown]
# ### Данные для первой части

# %% [markdown]
# Файл `/datasets/hypothesis.csv`
#
# * `Hypothesis` — краткое описание гипотезы;
#
# * `Reach` — охват пользователей по 10-балльной шкале;
#
# * `Impact` — влияние на пользователей по 10-балльной шкале;
#
# * `Confidence` — уверенность в гипотезе по 10-балльной шкале;
#
# * `Efforts` — затраты ресурсов на проверку гипотезы по 10-балльной шкале. Чем больше значение Efforts, тем дороже проверка гипотезы.

# %% [markdown]
# ### Данные для второй части

# %% [markdown]
# Файл `/datasets/orders.csv.`
#
# * `transactionId` — идентификатор заказа;
#
# * `visitorId` — идентификатор пользователя, совершившего заказ;
#
# * `date` — дата, когда был совершён заказ;
#
# * `revenue` — выручка заказа;
#
# * `group` — группа A/B-теста, в которую попал заказ.

# %% [markdown]
# Файл `/datasets/visitors.csv.`
#
# * `date` — дата;
#
# * `group` — группа A/B-теста;
#
# * `visitors` — количество пользователей в указанную дату в указанной группе A/B-теста.

# %% [markdown]
# ## Описание проекта

# %% [markdown]
# ### Часть 1. Приоритизация гипотез.

# %% [markdown]
# В файле `/datasets/hypothesis.csv` 9 гипотез по увеличению выручки интернет-магазина с указанными параметрами
# `Reach`, `Impact`, `Confidence`, `Effort`.
#
#
# **Задача**
#
# * Примените фреймворк `ICE` для приоритизации гипотез. Отсортируйте их по убыванию приоритета.
#
#
# * Примените фреймворк `RICE` для приоритизации гипотез. Отсортируйте их по убыванию приоритета.
#
#
# * Укажите, как изменилась приоритизация гипотез при применении `RICE` вместо `ICE`. Объясните, почему так произошло.

# %% [markdown]
# ### Часть 2. Анализ A/B-теста

# %% [markdown]
# Вы провели A/B-тест и получили результаты, которые описаны в файлах `/datasets/orders.csv` и `/datasets/visitors.csv`.
#
# **Задача**
#
# Проанализируйте A/B-тест:
#
# 1. Постройте график кумулятивной выручки по группам. Сделайте выводы и предположения.
#
# 2. Постройте график кумулятивного среднего чека по группам. Сделайте выводы и предположения.
#
# 3. Постройте график относительного изменения кумулятивного среднего чека группы B к группе A. Сделайте выводы и предположения.
#
# 4. Постройте график кумулятивного среднего количества заказов на посетителя по группам. Сделайте выводы и предположения.
#
# 5. Постройте график относительного изменения кумулятивного среднего количества заказов на посетителя группы B к группе A. Сделайте выводы и предположения.
#
# 6. Постройте точечный график количества заказов по пользователям. Сделайте выводы и предположения.
#
# 7. Посчитайте 95-й и 99-й перцентили количества заказов на пользователя. Выберите границу для определения аномальных пользователей.
#
# 8. Постройте точечный график стоимостей заказов. Сделайте выводы и предположения.
#
# 9. Посчитайте 95-й и 99-й перцентили стоимости заказов. Выберите границу для определения аномальных заказов.
#
# 10. Посчитайте статистическую значимость различий в среднем количестве заказов на посетителя между группами по «сырым» данным. Сделайте выводы и предположения.
#
# 11. Посчитайте статистическую значимость различий в среднем чеке заказа между группами по «сырым» данным. Сделайте выводы и предположения.
#
# 12. Посчитайте статистическую значимость различий в среднем количестве заказов на посетителя между группами по «очищенным» данным. Сделайте выводы и предположения.
#
# 13. Посчитайте статистическую значимость различий в среднем чеке заказа между группами по «очищенным» данным. Сделайте выводы и предположения.
#
# 14. Примите решение по результатам теста и объясните его. Варианты решений:
#     - Остановить тест, зафиксировать победу одной из групп.
#     - Остановить тест, зафиксировать отсутствие различий между группами.
#     - Продолжить тест.

# %% [markdown]
# <div class="alert alert-success">
# <b>Комментарий с комплиментом ревьюера:</b>
#
# Здорово, что описана цель проекта, описаны данные и выделено содержание.

# %% [markdown]
# ### Загрузка данных

# %%
# Импорт библиотек

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import math
import datetime as dt
import scipy.stats as stats
import warnings
from scipy import stats as st
from IPython.display import display
pd.set_option('display.max_colwidth', None)   # Вывод значений столбцов без обрезания
pd.options.display.max_colwidth = 130         # Расширенный вывод содержимого ячеек

# %%
# Открываем и сохраняем как датафрейм файл с данными:
try:
    
    hypothesis, orders, visitors = (
                            pd.read_csv('hypothesis.csv'),
                            pd.read_csv('orders.csv'),
                            pd.read_csv('visitors.csv')
                            )
except:
   
    hypothesis, orders, visitors = (
                            pd.read_csv('/datasets/hypothesis.csv'),
                            pd.read_csv('/datasets/orders.csv'),
                            pd.read_csv('/datasets/visitors.csv')
                            )

# %% [markdown]
# **Обзор общей информации датафреймов**

# %%
# Функция для вывода состава столбцов
def describe_cols(df_data):
    df = df_data
    values = pd.DataFrame()
    
    for col in df.columns:
        values[col] = [df[col].unique(), df[col].dtypes, df[col].nunique()]
        
    return values.transpose().sort_values(by=1, ascending=True).rename(
        {0: 'значения', 1: 'тип данных', 2: 'кол-во уникальных значений'}, axis=1)


# Функция для вывода пустых значений и их доли в столбцах датафрейма
def nan_values(df_data):
    df = df_data
    count_missing = df.isna().sum()
    percent_missing = round(df.isna().sum() * 100 / len(df), 2)
    
    missing_value_df = pd.DataFrame({'название_столбца': df.columns,
                                     'количество_пропусков': count_missing,
                                     'процент пропущенных значений': percent_missing})
    
    return missing_value_df


# Функция для вывода информации о файле
def df_info (df_data):
    display('Количество строк файла:', len(df_data))
    print()
    print('Информация о содержимом файла:')
    display(describe_cols(df_data))
    print()
    print('Информация о пропусках данных:')
    display(nan_values(df_data))
    print()
    print('Первые пять строк таблицы:')
    display(df_data.head())
    print('Количество явных дубликатов:', df_data.duplicated().sum())

# %% [markdown]
# <div class="alert alert-success">
# <b>Комментарий с комплиментом ревьюера:</b>
#
# Здорово, что написаны функции

# %% [markdown]
# **Датафрейм `hypothesis`:**

# %%
df_info(hypothesis)
# Out:
# 'Количество строк файла:'
# 9
# Информация о содержимом файла:
#                                                                                                                                      значения  \
# Reach                                                                                                                     [3, 2, 8, 5, 10, 1]
# Impact                                                                                                                 [10, 5, 3, 1, 2, 7, 9]
# Confidence                                                                                                              [8, 4, 7, 3, 1, 2, 9]
# Efforts                                                                                                                   [6, 10, 3, 8, 1, 5]
# Hypothesis  [Добавить два новых канала привлечения трафика, что позволит привлекать на 30% больше пользователей, Запустить собственную слу...
#
#            тип данных кол-во уникальных значений
# ...

# %% [markdown]
# >В файле содержится 9 строк.
# >В таблице представлены столбцы `Hypothesis`, `Reach`, `Impact`, `Confidence`, и `Effort` с различными типами данных и количеством уникальных значений.
# >Пропущенных данных нет.
# >Явных дубликатов строк также нет.

# %% [markdown]
# **Датафрейм `orders`:**

# %%
df_info(orders)
# Out:
# 'Количество строк файла:'
# 1197
# Информация о содержимом файла:
#                                                                                                                                         значения  \
# transactionId  [3667963787, 2804400009, 2961555356, 3797467345, 2282983706, 182168103, 398296753, 2626614568, 1576988021, 1506739906, 3649131...
# visitorId      [3312258926, 3642806036, 4069496402, 1196621759, 2322279887, 935554773, 2900797465, 78758296, 295230930, 1882260405, 879864040...
# revenue        [1650, 730, 400, 9759, 2308, 2210, 1860, 1044, 13710, 1855, 4008, 4499, 7370, 11985, 10980, 15277, 1060, 990, 16490, 1190, 300...
# date           [2019-08-15, 2019-08-16, 2019-08-01, 2019-08-22, 2019-08-17, 2019-08-23, 2019-08-02, 2019-08-18, 2019-08-24, 2019-08-03, 2019-...
# group                                                                                                                                     [B, A]
#
# ...

# %% [markdown]
# >В файле содержится 1197 строк.
# >В таблице представлены столбцы `transactionId`, `visitorId`, `date`, `revenue`, и `group` с различными типами данных и количеством уникальных значений.
# >Пропущенных данных нет.
# >Явных дубликатов строк также нет.

# %% [markdown]
# **Датафрейм `visitors`:**

# %%
df_info(visitors)
# Out:
# 'Количество строк файла:'
# 62
# Информация о содержимом файла:
#                                                                                                                                    значения  \
# visitors  [719, 619, 507, 717, 756, 667, 644, 610, 617, 406, 718, 595, 748, 735, 628, 361, 412, 668, 502, 575, 646, 609, 468, 395, 621, ...
# date      [2019-08-01, 2019-08-02, 2019-08-03, 2019-08-04, 2019-08-05, 2019-08-06, 2019-08-07, 2019-08-08, 2019-08-09, 2019-08-10, 2019-...
# group                                                                                                                                [A, B]
#
#          тип данных кол-во уникальных значений
# visitors      int64                         58
# date         object                         31
# group        object                          2
# Информация о пропусках данных:
#          название_столбца  количество_пропусков  процент пропущенных значений
# ...

# %% [markdown]
# >В файле содержится 62 строки.
# >В таблице представлены столбцы `date`, `group`, и `visitors` с различными типами данных и количеством уникальных значений.
# >Пропущенных данных нет.
# >Явных дубликатов строк также нет.

# %% [markdown]
# ### Предобработка данных

# %%
# Приведем наименования столбцов к хорошему стилю

hypothesis.columns = hypothesis.columns.str.lower()
orders.columns = [name.replace('Id', '_id') for name in orders.columns]

display(hypothesis.columns)
orders.columns
# Out:
# Index(['hypothesis', 'reach', 'impact', 'confidence', 'efforts'], dtype='object')
# Index(['transaction_id', 'visitor_id', 'date', 'revenue', 'group'], dtype='object')

# %%
# Изменим тип данных для столбцов с датами

visitors['date'] = pd.to_datetime(visitors['date'])
orders['date'] = pd.to_datetime(orders['date'])

# %%
visitors.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
#
# RangeIndex: 62 entries, 0 to 61
#
# Data columns (total 3 columns):
#
#  #   Column    Non-Null Count  Dtype
#
# ---  ------    --------------  -----
#
#  0   date      62 non-null     datetime64[ns]
#
#  1   group     62 non-null     object
#
#  2   visitors  62 non-null     int64
#
# dtypes: datetime64[ns](1), int64(1), object(1)
#
# memory usage: 1.6+ KB

# %%
orders.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
#
# RangeIndex: 1197 entries, 0 to 1196
#
# Data columns (total 5 columns):
#
#  #   Column          Non-Null Count  Dtype
#
# ---  ------          --------------  -----
#
#  0   transaction_id  1197 non-null   int64
#
#  1   visitor_id      1197 non-null   int64
#
#  2   date            1197 non-null   datetime64[ns]
#
#  3   revenue         1197 non-null   int64
#
#  4   group           1197 non-null   object
#
# dtypes: datetime64[ns](1), int64(3), object(1)
#
# memory usage: 46.9+ KB

# %%
hypothesis.sample()
# Out:
#                                                                                  hypothesis  \
# 5  Добавить страницу отзывов клиентов о магазине, что позволит увеличить количество заказов
#
#    reach  impact  confidence  efforts
# 5      3       2           2        3

# %%
orders.sample()
# Out:
#      transaction_id  visitor_id       date  revenue group
# 789       202241000  3062077384 2019-08-08     1993     B

# %% [markdown]
# >**Вывод:**
# >
# >* Данные датасетов загружены в датафреймы и подготовлены для дальнейшего анализа.
# >* Проверили данные на наличие пропусков (пропуски отсутствуют), наличие явных дубликатов (дубликаты отсутствуют),
# >соответствие типов данных (исправили тип данных в столбцах даты и времени),
# >* Исправили стилистические ошибки (привели названия всех столбцов в датафреймах к единому стилю).

# %% [markdown]
# **Посмотрим сколько групп в А/В-тесте:**

# %%
orders['group'].unique()
# Out:
# array(['B', 'A'], dtype=object)

# %% [markdown]
# Данные для А/В-теста представлены двумя группами - А и В.

# %% [markdown]
# **Рассмотрим количество пользователей в каждой группе - по таблице с заказами:**

# %%
# Подсчет количества уникальных пользователей в каждой группе по таблице с заказами
users_per_group = orders.groupby('group')['visitor_id'].nunique().reset_index()

users_per_group.columns = ['Группа', 'Количество пользователей']
users_per_group
# Out:
#   Группа  Количество пользователей
# 0      A                       503
# 1      B                       586

# %% [markdown]
# Количество пользователей в группе B больше, чем в группе А, примерно на 17%

# %% [markdown]
# <div class="alert alert-success">
# <b>Комментарий с комплиментом ревьюера:</b>
#
# Данные корректно подготовлены к работе.
# </div>

# %% [markdown]
# **Посмотрим динамику посетителей по дням для каждой группы:**

# %%
# Визуализация динамики посетителей по дням для каждой группы
plt.figure(figsize=(15, 5))
for group in visitors['group'].unique():
    subset = visitors[visitors['group'] == group]
    plt.plot(subset['date'], subset['visitors'], label=f"Группа {group}")

plt.title('Динамика посетителей по дням')
plt.xlabel('Дата')
plt.ylabel('Количество посетителей')
plt.legend()
plt.grid(True)
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %% [markdown]
# >Из графика видно, что динамика посетителей по дням совпадает в обеих группах, находится в диапазоне от 350 до 750 посетителей в день и имеет ярко выраженную цикличность.

# %% [markdown]
# <div class="alert alert-success">
# <b>Комментарий с комплиментом ревьюера:</b>
#
# Отлично
# </div>

# %% [markdown]
# ## Часть 1. Приоритизация гипотез

# %% [markdown]
# **Примените фреймворк `ICE` для приоритизации гипотез. Отсортируйте их по убыванию приоритета.**

# %%
# Применяем формулу ICE для приоритизации гипотез с округлением 
hypothesis['ICE'] = ((hypothesis['impact'] * hypothesis['confidence']) / hypothesis['efforts']).round(2)

# Сортируем гипотезы по убыванию приоритета
sorted_hypothesis = hypothesis[['hypothesis', 'ICE']].sort_values(by='ICE', ascending=False)

sorted_hypothesis
# Out:
#                                                                                                      hypothesis  \
# 8                                                       Запустить акцию, дающую скидку на товар в день рождения
# 0            Добавить два новых канала привлечения трафика, что позволит привлекать на 30% больше пользователей
# 7              Добавить форму подписки на все основные страницы, чтобы собрать базу клиентов для email-рассылок
# 6          Показать на главной странице баннеры с актуальными акциями и распродажами, чтобы увеличить конверсию
# 2  Добавить блоки рекомендаций товаров на сайт интернет магазина, чтобы повысить конверсию и средний чек заказа
# 1                                     Запустить собственную службу доставки, что сократит срок доставки заказов
# 5                      Добавить страницу отзывов клиентов о магазине, что позволит увеличить количество заказов
# ...

# %%
# Визуализация приоритета гипотез по ICE

plt.figure(figsize=(12, 8))
sns.barplot(x='ICE', y='hypothesis', data=sorted_hypothesis, orient='h', palette='viridis')
plt.title('Приоритет гипотез по ICE', fontsize=16)
plt.xlabel('Значение ICE', fontsize=14)
plt.ylabel('Гипотезы', fontsize=14)
plt.xticks(fontsize=12)
plt.yticks(fontsize=12)
plt.show()

# %% [markdown]
# >Применяя фреймворк ICE для приоритизации гипотез, мы получили следующие наиболее приоритетные гипотезы:
# >
# >* Запустить акцию, дающую скидку на товар в день рождения.
# >* Добавить два новых канала привлечения трафика, что позволит привлекать на 30% больше пользователей.
# >* Добавить форму подписки на все основные страницы, чтобы собрать базу клиентов для email-рассылок.
# >
# >Эти гипотезы имеют наибольшее значение ICE, что говорит о высокой степени их влияния, уверенности в успешности и относительно низкой стоимости проверки.

# %% [markdown]
# <div class="alert alert-success">
# <b>Комментарий с комплиментом ревьюера:</b>
#
# Здорово, что добавил визуализацию;
# </div>

# %% [markdown]
# **Примените фреймворк `RICE` для приоритизации гипотез. Отсортируйте их по убыванию приоритета.**

# %%
# Применяем формулу RICE для приоритизации гипотез
hypothesis['RICE'] = (hypothesis['reach'] * hypothesis['impact'] * hypothesis['confidence']) / hypothesis['efforts']

# Сортируем гипотезы по убыванию приоритета
sorted_hypothesis_rice = hypothesis[['hypothesis', 'RICE']].sort_values(by='RICE', ascending=False)

sorted_hypothesis_rice
# Out:
#                                                                                                      hypothesis  \
# 7              Добавить форму подписки на все основные страницы, чтобы собрать базу клиентов для email-рассылок
# 2  Добавить блоки рекомендаций товаров на сайт интернет магазина, чтобы повысить конверсию и средний чек заказа
# 0            Добавить два новых канала привлечения трафика, что позволит привлекать на 30% больше пользователей
# 6          Показать на главной странице баннеры с актуальными акциями и распродажами, чтобы увеличить конверсию
# 8                                                       Запустить акцию, дающую скидку на товар в день рождения
# 3           Изменить структура категорий, что увеличит конверсию, т.к. пользователи быстрее найдут нужный товар
# 1                                     Запустить собственную службу доставки, что сократит срок доставки заказов
# ...

# %%
# Визуализация приоритета гипотез по RICE

plt.figure(figsize=(12, 8))
sns.barplot(x='RICE', y='hypothesis', data=hypothesis.sort_values(by='RICE', ascending=False), orient='h', palette='magma')
plt.title('Приоритет гипотез по RICE', fontsize=16)
plt.xlabel('Значение RICE', fontsize=14)
plt.ylabel('Гипотезы', fontsize=14)
plt.xticks(fontsize=12)
plt.yticks(fontsize=12)
plt.show()

# %% [markdown]
# >Применяя фреймворк RICE для приоритизации гипотез, мы получили следующие наиболее приоритетные гипотезы:
# >
# >* Добавить форму подписки на все основные страницы, чтобы собрать базу клиентов для email-рассылок.
# >* Добавить блоки рекомендаций товаров на сайт интернет магазина, чтобы повысить конверсию и средний чек заказа.
# >* Добавить два новых канала привлечения трафика, что позволит привлекать на 30% больше пользователей.
# >
# >Эти гипотезы имеют наибольшее значение RICE, что говорит о высокой степени их влияния, уверенности в успешности, относительно низкой стоимости проверки и большом охвате пользователей.
# >
# >Отличие RICE от ICE: В отличие от `ICE`, фреймворк `RICE` включает в себя параметр "Reach" (охват), который показывает, сколько пользователей затронут изменения, которые вы планируете внести. Этот параметр оказался ключевым для изменения приоритизации гипотез.

# %%
# Создаем таблицу для сравнения RICE и ICE
data = {
    'Компоненты': ['Impact (влияние)', 'Confidence (уверенность)', 'Effort (усилия)', 'Reach (охват)'],
    'ICE': ['✓', '✓', '✓', '—'],
    'RICE': ['✓', '✓', '✓', '✓'],
    'Описание': [
        'Оценка того, как изменения повлияют на пользователей или бизнес.',
        'Насколько вы уверены в своих оценках влияния, охвата и усилий.',
        'Как много ресурсов потребуется для реализации данной гипотезы или изменения.',
        'Количество пользователей, которых затронет это изменение в течение определенного временного периода.'
    ]
}

comparison_table = pd.DataFrame(data)

comparison_table
# Out:
#                  Компоненты ICE RICE  \
# 0          Impact (влияние)   ✓    ✓
# 1  Confidence (уверенность)   ✓    ✓
# 2           Effort (усилия)   ✓    ✓
# 3             Reach (охват)   —    ✓
#
#                                                                                                Описание
# 0                                      Оценка того, как изменения повлияют на пользователей или бизнес.
# 1                                        Насколько вы уверены в своих оценках влияния, охвата и усилий.
# 2                          Как много ресурсов потребуется для реализации данной гипотезы или изменения.
# 3  Количество пользователей, которых затронет это изменение в течение определенного временного периода.

# %% [markdown]
# >**Impact (Влияние):**
# >Присутствует в обоих фреймворках.
# >Отражает, насколько сильно предлагаемое изменение может повлиять на ключевые показатели или пользовательский опыт.
# >
# >**Confidence (Уверенность):**
# >Также включено в оба фреймворка.
# >Отражает уровень уверенности в оценках других параметров (например, в оценке влияния или усилий).
# >
# >**Effort (Усилия):**
# >Есть в обоих методах.
# >Показывает, сколько ресурсов (времени, денег, труда) потребуется, чтобы реализовать данное изменение или проверить гипотезу.
# >
# >**Reach (Охват):**
# >Только в RICE.
# >Оценивает, сколько пользователей затронет данное изменение. Это может быть важно для проектов, где предполагаемые изменения имеют разный охват среди аудитории.

# %%
hypothesis[['hypothesis','ICE', 'RICE']].sort_values(by='RICE', ascending=False).head(5)
# Out:
#                                                                                                      hypothesis  \
# 7              Добавить форму подписки на все основные страницы, чтобы собрать базу клиентов для email-рассылок
# 2  Добавить блоки рекомендаций товаров на сайт интернет магазина, чтобы повысить конверсию и средний чек заказа
# 0            Добавить два новых канала привлечения трафика, что позволит привлекать на 30% больше пользователей
# 6          Показать на главной странице баннеры с актуальными акциями и распродажами, чтобы увеличить конверсию
# 8                                                       Запустить акцию, дающую скидку на товар в день рождения
#
#      ICE   RICE
# 7  11.20  112.0
# 2   7.00   56.0
# 0  13.33   40.0
# 6   8.00   40.0
# 8  16.20   16.2

# %% [markdown]
# >* Гипотезы с наивысшим значением RICE также имеют высокие значения ICE, что говорит о их потенциальной эффективности.
# >
# >* Но из-за введения параметра "Reach" в RICE, приоритеты могут сместиться по сравнению с ICE. Это потому что RICE учитывает количество пользователей, которых затронет данное изменение.
# >
# >* Гипотезы с высоким охватом будут иметь более высокий приоритет в RICE по сравнению с ICE.

# %% [markdown]
# **Вывод:**
# >
# >* Оба фреймворка (ICE и RICE) предназначены для оценки и приоритизации идей или гипотез на основе влияния, уверенности и усилий.
# >
# >* Отличие RICE заключается в добавлении параметра `Reach` "охват", что делает его особенно полезным для проектов, где ожидаемые изменения затрагивают разное количество пользователей.
# >
# >* Выбор между ICE и RICE зависит от специфики проекта. Если охват не является ключевым параметром, ICE может быть предпочтительнее. Если же вам важно учитывать, сколько пользователей затронет изменение, RICE будет лучшим выбором.

# %% [markdown]
# <div class="alert alert-success">
# <b>Комментарий с комплиментом ревьюера:</b>
#
# Гипотезы проанализированы верно, молодец.
#
# Здорово, что указано на изменение приоритетов при учете охвата.
# </div>

# %% [markdown]
# ## Часть 2. Анализ A/B-теста

# %% [markdown]
# ### 1. Постройте график кумулятивной выручки по группам. Сделайте выводы и предположения.

# %% [markdown]
# Мы провели A/B-тест и получили результаты, которые описаны в файлах `/datasets/orders.csv` и `/datasets/visitors.csv`.

# %%
display(orders.head())
display(visitors.head())
# Out:
#    transaction_id  visitor_id       date  revenue group
# 0      3667963787  3312258926 2019-08-15     1650     B
# 1      2804400009  3642806036 2019-08-15      730     B
# 2      2961555356  4069496402 2019-08-15      400     A
# 3      3797467345  1196621759 2019-08-15     9759     B
# 4      2282983706  2322279887 2019-08-15     2308     B
#         date group  visitors
# 0 2019-08-01     A       719
# 1 2019-08-02     A       619
# 2 2019-08-03     A       507
# 3 2019-08-04     A       717
# 4 2019-08-05     A       756

# %%
# Подсчет общего количества пользователей, принявших участие в тесте
total_users = orders['visitor_id'].nunique()
total_users
# Out:
# 1031

# %%
# Находим пользователей, которые попали в обе группы
users_in_both_groups = orders.groupby('visitor_id').agg({'group': 'nunique'}).query('group > 1')

# Получаем количество таких пользователей
users_in_both_groups_count = users_in_both_groups.shape[0]
users_in_both_groups_count
# Out:
# 58

# %% [markdown]
# <div class="alert alert-warning">
# <b>Комментарий с советом ревьюера:</b>
#
# Здорово, что пересекающиеся пользователи обработаны. Всегда необходимо обращать внимание на такие ошибки, но надо внимательно относиться к обработке таких данных.
#
# Одни и те же пользователи попали в две группы теста — это говорит об ошибке в сборе данных. В нашем случае удаление этих пользователей повлияет на конверсию, поскольку мы можем удалить этих пользователей из таблицы с заказами, но не сможем удалить из таблицы с визитами, поскольку там данные уже агрегированы за день.
#
# Также всегда лучше анализировать долю данных, которую удаляешь. Если доля составляет меньше 1%,  то такие данные не сильно повлияют на результат и их можно оставить.
#   </div>

# %% [markdown]
# <div class="alert alert-info"> <b>Комментарий студента:</b> Согласен, обработка данных, в том числе и обнаружение и коррекция ошибок, является важным этапом в анализе. Удаление пересекающихся пользователей может повлиять на результаты теста, и важно оценить потенциальное влияние такого удаления на интерпретацию результатов.
#
# Спасибо за важное замечание относительно доли данных, которую следует удалить. Это действительно важно учитывать при принятии решений об обработке данных.</div>

# %% [markdown]
# <div class="alert alert-success">
# <b>Комментарий с комплиментом ревьюера в2:</b>
#
# Отлично

# %%
# Создаем массив уникальных пар значений дат и групп теста
datesGroups = orders[['date', 'group']].drop_duplicates()

# Собираем агрегированные кумулятивные по дням данные о заказах 
ordersAggregated = datesGroups.apply(
    lambda x: orders[
        np.logical_and(
            orders['date'] <= x['date'], orders['group'] == x['group']
        )
    ].agg(
        {
            'date': 'max',
            'group': 'max',
            'transaction_id': pd.Series.nunique,
            'visitor_id': pd.Series.nunique,
            'revenue': 'sum',
        }
    ),
    axis=1,
).sort_values(by=['date', 'group'])

# Собираем агрегированные кумулятивные по дням данные о посетителях 
visitorsAggregated = datesGroups.apply(
    lambda x: visitors[
        np.logical_and(
            visitors['date'] <= x['date'], visitors['group'] == x['group']
        )
    ].agg({'date': 'max', 'group': 'max', 'visitors': 'sum'}),
    axis=1,
).sort_values(by=['date', 'group'])

# Объединяем кумулятивные данные в одной таблице и присваиваем ее столбцам понятные названия
cumulativeData = ordersAggregated.merge(visitorsAggregated, left_on=['date', 'group'], right_on=['date', 'group'])
cumulativeData.columns = ['date', 'group', 'orders', 'buyers', 'revenue', 'visitors']

# Датафрейм с кумулятивным количеством заказов и кумулятивной выручкой по дням в группе А
cumulativeRevenueA = cumulativeData[cumulativeData['group'] == 'A'][['date', 'revenue', 'orders']]

# Датафрейм с кумулятивным количеством заказов и кумулятивной выручкой по дням в группе B
cumulativeRevenueB = cumulativeData[cumulativeData['group'] == 'B'][['date', 'revenue', 'orders']]

# Построение графика кумулятивной выручки по группам
plt.figure(figsize=(15, 6))
plt.plot(cumulativeRevenueA['date'], cumulativeRevenueA['revenue'], label='A')
plt.plot(cumulativeRevenueB['date'], cumulativeRevenueB['revenue'], label='B')
plt.title('Кумулятивная выручка по группам')
plt.xlabel('Дата')
plt.ylabel('Выручка')
plt.legend()
plt.xticks(rotation=45)
plt.grid(True)
plt.tight_layout()
plt.show()

# %% [markdown]
# **Выводы и предположения:**
#
# >1. В начале теста выручка обеих групп росла примерно одинаково и показывала небольшие колебания.
# >
# >2. Однако после 5 августа группа B показала резкий рост выручки. Этот момент совпадает с резким увеличением среднего чека для этой группы, что мы рассматривали ранее. Скорее всего, это связано с наличием крупных заказов.
# >
# >3. После этого резкого роста выручка группы B продолжала увеличиваться, хотя и не так стремительно.
# >
# >4. Группа A также показывала устойчивый рост, но без резких всплесков.
# >
# >Таким образом, на основе анализа этого графика можно предположить, что в группе B были крупные заказы, которые искажали общую картину. После "очистки" данных от этих аномальных заказов картина может измениться. Несмотря на это, стоит отметить, что к концу месяца кумулятивная выручка группы B значительно превосходила выручку группы A.

# %% [markdown]
# ***Возможные причины такого поведения графика:***
# >
# >**Большие заказы:** Если в определенный день было сделано несколько крупных заказов, это может вызвать резкий скачок в кумулятивной выручке. Это особенно вероятно, если до этого момента таких крупных заказов не было.
# >
# >**Увеличение количества заказов:** Может быть ситуация, когда количество заказов увеличивается внезапно из-за какой-либо акции, рекламной кампании или другого маркетингового мероприятия.
# >
# >**Сезонность:** В определенное время года (например, праздничные или предпраздничные дни) может быть увеличение покупательской активности, что приведет к резкому росту выручки.
# >
# >**Технические ошибки:** Иногда ошибки при интеграции платежных систем или при обработке заказов могут дублировать записи, что приведет к увеличению выручки на графике.
# >
# >**Изменения на сайте:** Если были произведены какие-либо значительные изменения на сайте или добавлены новые функции, которые стимулируют пользователей к покупке, это может привести к увеличению выручки.
# >
# >**Влияние внешних факторов:** Новости, статьи, рекламные кампании в других источниках или другие внешние события могут привести к резкому росту интереса к продукту и, соответственно, увеличению выручки.
# >
# >**Влияние других тестов:** Если одновременно проводится несколько A/B тестов на сайте, они могут влиять друг на друга и искажать результаты.

# %% [markdown]
# <div class="alert alert-success">
# <b>Комментарий с комплиментом ревьюера:</b>
#
# График интерпретирован верно, здорово, что выдвинуто предположение природы появления всплеска.
# </div>

# %% [markdown]
# ### 2. Постройте график кумулятивного среднего чека по группам. Сделайте выводы и предположения.

# %%
# Считаем кумулятивную выручку по дням и группам A/B
cumulativeRevenueA = cumulativeData[cumulativeData['group'] == 'A'][['date', 'revenue', 'orders']]
cumulativeRevenueB = cumulativeData[cumulativeData['group'] == 'B'][['date', 'revenue', 'orders']]

plt.figure(figsize=(15, 7))

# Делим кумулятивную выручку на кумулятивное число заказов, чтобы получить средний чек
plt.plot(cumulativeRevenueA['date'], cumulativeRevenueA['revenue'] / cumulativeRevenueA['orders'], label='A')
plt.plot(cumulativeRevenueB['date'], cumulativeRevenueB['revenue'] / cumulativeRevenueB['orders'], label='B')

plt.title('Кумулятивный средний чек по группам')
plt.xlabel('Дата')
plt.ylabel('Средний чек')
plt.legend()
plt.xticks(rotation=45)
plt.grid(True)
plt.tight_layout()
plt.show()

# %% [markdown]
# **Анализ графика:**
#
# >* Группа А: Средний чек вначале растет, а затем стабилизируется. Ближе к концу теста наблюдается небольшое снижение.
# >
# >* Группа В: Средний чек сначала немного растет, потом наблюдается резкий скачок (скорее всего из-за крупных заказов или аномалий), после чего начинает постепенно снижаться, стремясь к среднему чеку группы А.
# >
# **Выводы и предположения:**
#
# >* График среднего чека группы B в определенный момент времени резко увеличивается, что может свидетельствовать о наличии крупных заказов или других аномалий в этот день.
# >* После этого скачка средний чек группы B начинает постепенно уменьшаться. Это может говорить о том, что с течением времени крупные заказы или аномалии становятся менее значимыми для общего расчета среднего чека.
# >* Средний чек группы A становится стабильным к концу теста, что говорит о его стабильности и надежности в сравнении со средним чеком группы B.

# %% [markdown]
# <div class="alert alert-success">
# <b>Комментарий с комплиментом ревьюера:</b>
#
# Согласен с выводом по графику.
# </div>

# %% [markdown]
# ### 3. Постройте график относительного изменения кумулятивного среднего чека группы B к группе A. Сделайте выводы и предположения.

# %%
# Объединение данных по кумулятивным выручкам групп A и B
mergedCumulativeRevenue = cumulativeRevenueA.merge(cumulativeRevenueB, on='date', how='left', suffixes=['A', 'B'])

# Построение графика относительного изменения кумулятивного среднего чека группы B к группе A
plt.figure(figsize=(15, 7))
plt.plot(mergedCumulativeRevenue['date'], 
         (mergedCumulativeRevenue['revenueB']/mergedCumulativeRevenue['ordersB']) / 
         (mergedCumulativeRevenue['revenueA']/mergedCumulativeRevenue['ordersA']) - 1)

# Добавление оси X
plt.axhline(y=0, color='black', linestyle='--')

plt.title('Относительное изменение кумулятивного среднего чека группы B к группе A')
plt.xlabel('Дата')
plt.ylabel('Относительное изменение')
plt.xticks(rotation=45)
plt.grid(True)
plt.tight_layout()
plt.show()

# %% [markdown]
# **Выводы и предположения:**
#
# >**Начало теста:**
# >* В начале теста график сильно колеблется, что может быть связано с неравномерным поступлением заказов или наличием крупных заказов в одной из групп.
# >
# >**Резкий скачок:**
# >* Наблюдается резкий всплеск в пользу группы B, что совпадает с резким увеличением среднего чека в группе B на предыдущем графике. Это может указывать на наличие аномально дорогих заказов в группе B в этот период.
# >
# >**Последующий период:**
# >* После пика график начинает постепенно снижаться, что может говорить о "растворении" крупных заказов в общем потоке данных с течением времени. К концу теста различие между группами уменьшается, но группа B все равно остается лидером по среднему чеку.
# >
# **Общие замечания:**
# >Относительное изменение среднего чека сильно колеблется в течение всего теста. Это может говорить о наличии выбросов или аномалий в данных.

# %% [markdown]
# <div class="alert alert-success">
# <b>Комментарий с комплиментом ревьюера:</b>
#
# Сначала средний чек группы B стабильно растет, потом резко падает и снова растет. Согласен, влияние крупных заказов.
# </div>

# %% [markdown]
# ### 4. Постройте график кумулятивного среднего количества заказов на посетителя по группам. Сделайте выводы и предположения.

# %%
# Расчет кумулятивного среднего количества заказов на посетителя по группам
cumulativeOrdersPerVisitorA = cumulativeRevenueA['orders'] / cumulativeData[cumulativeData['group'] == 'A']['visitors']
cumulativeOrdersPerVisitorB = cumulativeRevenueB['orders'] / cumulativeData[cumulativeData['group'] == 'B']['visitors']

plt.figure(figsize=(15, 7))
plt.plot(cumulativeRevenueA['date'], cumulativeOrdersPerVisitorA, label='A')
plt.plot(cumulativeRevenueB['date'], cumulativeOrdersPerVisitorB, label='B')
plt.title('Кумулятивное среднее количество заказов на посетителя по группам')
plt.xlabel('Дата')
plt.ylabel('Среднее количество заказов на посетителя')
plt.legend()
plt.xticks(rotation=45)
plt.grid(True)
plt.tight_layout()
plt.show()

# %% [markdown]
# **Выводы:**
#
# >**1. Стабильность в группе А:** Кумулятивное среднее количество заказов на посетителя в группе A в большей части экспериментального периода остается стабильным. Это может свидетельствовать о том, что поведение пользователей в группе A не претерпело существенных изменений в течение теста.
# >**2. Всплеск в группе В:** В начале экспериментального периода в группе B наблюдается резкий всплеск среднего количества заказов на посетителя, но затем этот показатель сходится с показателем группы A и остается на схожем уровне до конца периода.
# >
# **Предположения:**
# >
# >* **Причина всплеска в группе В:** Возможно, в начале теста в группе B была проведена какая-то маркетинговая акция или рекламная кампания, что привело к увеличению активности пользователей. Это также могло быть вызвано наличием аномально активных пользователей, которые совершили множество заказов в первые дни теста.
# >* **Конвергенция групп:** После начального всплеска обе группы стабилизировались, и их показатели стали схожими. Это может свидетельствовать о том, что в долгосрочной перспективе изменения, внесенные в тесте, не оказали значительного влияния на поведение пользователей в плане частоты покупок.

# %% [markdown]
# <div class="alert alert-success">
# <b>Комментарий с комплиментом ревьюера:</b>
#
# Отличный анализ, молодец.
# </div>

# %% [markdown]
# ### 5. Постройте график относительного изменения кумулятивного среднего количества заказов на посетителя группы B к группе A.   Сделайте выводы и предположения.

# %%
# Объединение данных по кумулятивным заказам на посетителя групп A и B
mergedCumulativeOrdersPerVisitor = pd.DataFrame({
    'date': cumulativeRevenueA['date'],
    'ordersPerVisitorA': cumulativeOrdersPerVisitorA.values,
    'ordersPerVisitorB': cumulativeOrdersPerVisitorB.values
})

# Построение графика относительного изменения кумулятивного среднего количества заказов на посетителя группы B к группе A
plt.figure(figsize=(15, 7))
plt.plot(mergedCumulativeOrdersPerVisitor['date'], 
         mergedCumulativeOrdersPerVisitor['ordersPerVisitorB'] / mergedCumulativeOrdersPerVisitor['ordersPerVisitorA'] - 1)

# Добавление оси X
# plt.axhline(y=0, color='black', linestyle='--')

# plt.axhline(y=0.1, color='gray', linestyle='--')
# plt.axhline(y=0.2, color='gray', linestyle='--')

plt.axhline(y=0, color='black', linestyle='--')
plt.axhline(y=0.1, color='red', linestyle='--', label='10% отклонение')
plt.axhline(y=0.2, color='blue', linestyle='--', label='20% отклонение')


plt.title('Относительное изменение кумулятивного среднего количества заказов на посетителя группы B к группе A')
plt.xlabel('Дата')
plt.ylabel('Относительное изменение')
plt.xticks(rotation=45)
plt.grid(True)
plt.tight_layout()
plt.show()

# %% [markdown]
# **Выводы и предположения:**
#
# >**1. Начало теста:** В начале теста группа B имела больше заказов на посетителя по сравнению с группой A.
# >**2. Середина теста:** К середине теста группа B теряет свои преимущества, и её показатели почти сравниваются с группой A. Затем группа B снова начинает набирать преимущество.
# >**3. Конец теста:** К концу теста относительное изменение кумулятивного среднего количества заказов на посетителя группы B к группе A колеблется около 0, что указывает на отсутствие существенных различий между группами.
# >
# >Таким образом, несмотря на начальные отличия, к концу теста среднее количество заказов на посетителя в группах A и B становится схожим. Это может свидетельствовать о том, что изменения, внесенные в ходе теста, не оказали существенного влияния на поведение пользователей в плане количества заказов на одного посетителя.
#
# >*После начальных колебаний относительное изменение стабилизировалось между линиями 0.1 и 0.2. Это означает, что среднее количество заказов на посетителя в группе B стабильно выше на 10-20% по сравнению с группой A.*

# %% [markdown]
# <div class="alert alert-warning">
# <b>Комментарий с советом ревьюера:</b>
#
# На график лучше добавить еще две axhline на уровне 0.1 и 0.2, чтобы показать на каком уровне стабилизировалось среднее количества заказов
# </div>

# %% [markdown]
# <div class="alert alert-info"> <b>Комментарий студента:</b> Добавил две axhline, дополнил вывод.</div>

# %% [markdown]
# <div class="alert alert-success">
# <b>Комментарий с комплиментом ревьюера в2:</b>
#
# Отлично

# %% [markdown]
# ### 6. Постройте точечный график количества заказов по пользователям. Сделайте выводы и предположения.

# %% [markdown]
# Создадим переменные по группам А и В , в которых сформируем данные по пользователям и количеству заказов каждого (по тем, кто совершил хоть один заказ):

# %%
# Формирование данных по пользователям и количеству заказов для групп A и B
orders_by_users_A = orders[orders['group'] == 'A'].groupby('visitor_id', as_index=False).agg({'transaction_id': 'nunique'})\
                                                                              .rename(columns={'transaction_id': 'orders'})
orders_by_users_B = orders[orders['group'] == 'B'].groupby('visitor_id', as_index=False).agg({'transaction_id': 'nunique'})\
                                                                              .rename(columns={'transaction_id': 'orders'})

orders_by_users_A.head()
# Out:
#    visitor_id  orders
# 0     8300375       1
# 1    11685486       1
# 2    54447517       1
# 3    66685450       1
# 4    78758296       1

# %%
orders_by_users_B.head()
# Out:
#    visitor_id  orders
# 0     5114589       1
# 1     6958315       1
# 2     8300375       1
# 3    39475350       1
# 4    47206413       1

# %%
# Визуализация данных по количеству заказов для пользователей групп A и B

plt.figure(figsize=(15, 7))

# Точечный график для группы A
plt.scatter(orders_by_users_A['visitor_id'], orders_by_users_A['orders'], alpha=0.6, edgecolors='black', label='Группа A')

# Точечный график для группы B
plt.scatter(orders_by_users_B['visitor_id'], orders_by_users_B['orders'], alpha=0.6, edgecolors='red', color='orange', label='Группа B')

plt.title('Точечный график количества заказов по пользователям для групп A и B')
plt.xlabel('Пользователи')
plt.ylabel('Количество заказов')
plt.xticks(rotation=45)
plt.legend()
plt.grid(True, which='both', linestyle='--', linewidth=0.5)
plt.tight_layout()
plt.show()

# %% [markdown]
# **Выводы:**
#
# >1. Большинство пользователей в обеих группах совершили только один заказ. Это основная масса точек у оси Y, равной 1.
# >2. Некоторые пользователи в обеих группах совершили 2 или 3 заказа.
# >3. Очень мало пользователей в обеих группах, которые совершили 4 или более заказов.
# >
# **Предположения:**
# >
# >Есть небольшой процент пользователей, которые совершают множество заказов. Это могут быть "оптовые" клиенты или очень активные пользователи.
# Таким образом, распределение количества заказов среди пользователей выглядит схожим для обеих групп. На графике видно, что аномальные пользователи (те, кто совершил 4 и более заказов) присутствуют и в группе A, и в группе B.

# %% [markdown]
# <div class="alert alert-success">
# <b>Комментарий с комплиментом ревьюера:</b>
#
# Отличный анализ, можно предположить, что граница нормальных и аномальных пользователей проходит примерно на уровне 3-4 заказа на одного пользователя.
# <div>

# %% [markdown]
# ### 7. Посчитайте 95-й и 99-й перцентили количества заказов на пользователя. Выберите границу для определения аномальных пользователей.

# %%
# Группировка данных по пользователям и расчет количества заказов
orders_by_users = orders.groupby('visitor_id', as_index=False)\
.agg({'transaction_id': 'nunique'}).rename(columns={'transaction_id': 'orders'})

# Расчет 95-го и 99-го перцентилей количества заказов на пользователя
percentiles = np.percentile(orders_by_users['orders'], [95, 99])

percentiles
# Out:
# array([2., 4.])

# %% [markdown]
# **Вывод:**
#
# * Не более 5% пользователей совершили более 2 заказов.
# * Не более 1% пользователей совершили более 4 заказов.

# %%
# Расчет 95-го и 99-го перцентилей количества заказов на пользователя для группы A
orders_by_users_A = orders[orders['group'] == 'A'].groupby('visitor_id', as_index=False).agg({'transaction_id': 'nunique'}).rename(columns={'transaction_id': 'orders'})
percentiles_A = np.percentile(orders_by_users_A['orders'], [95, 99])

# Расчет 95-го и 99-го перцентилей количества заказов на пользователя для группы B
orders_by_users_B = orders[orders['group'] == 'B'].groupby('visitor_id', as_index=False).agg({'transaction_id': 'nunique'}).rename(columns={'transaction_id': 'orders'})
percentiles_B = np.percentile(orders_by_users_B['orders'], [95, 99])

percentiles_A,  percentiles_B
# Out:
# (array([2.  , 3.98]), array([2.  , 3.15]))

# %% [markdown]
# **Результаты по перцентилям для групп A и B:**
#
# >**Группа A:**
# >
# >* 95-й перцентиль: 2 заказа
# >* 99-й перцентиль: 3.98 заказа (округлим до 4 заказов)
# >
# >**Группа B:**
# >
# >* 95-й перцентиль: 2 заказа
# >* 99-й перцентиль: 3.15 заказа (округлим до 4 заказов)
# >
# **Вывод:**
#
# >Для обеих групп результаты практически идентичны. Не более 5% пользователей совершили более 2 заказов, и не более 1% пользователей совершили 4 или более заказа.
# >Это означает, что граница для определения аномальных пользователей может быть одинаковой для обеих групп и составлять 2 заказа. Таким образом, пользователи, совершившие 3 или более заказа, будут считаться аномальными в обеих группах.

# %% [markdown]
# <div class="alert alert-success">
# <b>Комментарий с комплиментом ревьюера:</b>
#
# 95-й и 99-й перцентили определены верно, нижняя граница числа заказов выбрана корректно, молодец.</div>

# %% [markdown]
# ### 8. Постройте точечный график стоимостей заказов. Сделайте выводы и предположения.

# %%
# Точечный график стоимостей заказов
plt.figure(figsize=(15, 7))
plt.scatter(orders['transaction_id'], orders['revenue'], alpha=0.6, edgecolors='black')
plt.title('Точечный график стоимостей заказов')
plt.xlabel('Заказы (ID транзакции)')
plt.ylabel('Стоимость заказа')
plt.grid(True, which='both', linestyle='--', linewidth=0.5)
plt.tight_layout()
plt.show()

# %%
# Точечный график стоимостей заказов
plt.figure(figsize=(15, 7))
plt.scatter(orders['transaction_id'], orders['revenue'], alpha=0.6, edgecolors='black')
plt.title('Точечный график стоимостей заказов')
plt.xlabel('Заказы (ID транзакции)')
plt.ylabel('Стоимость заказа')
plt.grid(True, which='both', linestyle='--', linewidth=0.5)
plt.ylim(0,100000)
plt.tight_layout()
plt.show()

# %% [markdown]
# **Наблюдения:**
#
# >1. Большинство заказов имеют стоимость меньше 100,000 у.е.
# >
# >2. Есть несколько заказов со стоимостью около 200,000 у.е. и один заказ, который выделяется с существенно большей стоимостью — около 1,200,000 у.е.
#
# **Выводы:**
#
# >* В данных присутствуют аномальные значения стоимости заказов, которые могут исказить результаты A/B теста.
# >* Для дальнейшего анализа может потребоваться исключение этих аномалий или корректировка методов анализа для учета таких выбросов.
#
# **Предположения:**
#
# >Наиболее вероятной причиной таких аномалий может быть наличие оптовых заказов или заказов с большим количеством дорогостоящих товаров.
# >Также возможно, что в данных присутствуют ошибки или искажения.

# %% [markdown]
# <div class="alert alert-success">
# <b>Комментарий с комплиментом ревьюера:</b>
#
# Здорово, что применено ограничение по оси Y и детально проанализированы данные. </div>

# %% [markdown]
# ### 9. Посчитайте 95-й и 99-й перцентили стоимости заказов. Выберите границу для определения аномальных заказов.

# %%
# Расчет 95-го и 99-го перцентилей стоимости заказов
order_percentiles = np.percentile(orders['revenue'], [95, 99])

order_percentiles
# Out:
# array([28000. , 58233.2])

# %% [markdown]
# 95-й и 99-й перцентили стоимости заказов составляют соответственно 28,000 и 58,233.2 у.е.
#
# **Вывод:**
#
# >* Не более 5% заказов имеют стоимость выше 28,000 у.е.
# >* Не более 1% заказов имеют стоимость выше 58,233.2 у.е.
# >
# >Для определения аномальных заказов можно использовать границу в 28,000 у.е.
# Таким образом, заказы со стоимостью выше этой суммы будут считаться аномальными.

# %%
# Расчет 95-го и 99-го перцентилей стоимости заказов для группы A
order_percentiles_A = np.percentile(orders[orders['group'] == 'A']['revenue'], [95, 99])

# Расчет 95-го и 99-го перцентилей стоимости заказов для группы B
order_percentiles_B = np.percentile(orders[orders['group'] == 'B']['revenue'], [95, 99])

order_percentiles_A, order_percentiles_B
# Out:
# (array([26718. , 62764.4]), array([28787.45, 55579.06]))

# %% [markdown]
# **Результаты по перцентилям стоимости заказов для групп A и B:**
#
# >**Группа A:**
# >
# >* 95-й перцентиль: 26,718 у.е.
# >* 99-й перцентиль: 62,764.4 у.е.
# >
# >**Группа B:**
# >
# >* 95-й перцентиль: 28,787.45 у.е.
# >* 99-й перцентиль: 55,579.06 у.е.
# >
# **Вывод:**
# >
# >* Для группы A заказы стоимостью выше 26,718 у.е. входят в 5% самых дорогих, и заказы стоимостью выше 62,764.4 у.е. входят в 1% самых дорогих.
# >* Для группы B заказы стоимостью выше 28,787.45 у.е. входят в 5% самых дорогих, и заказы стоимостью выше 55,579.06 у.е. входят в 1% самых дорогих.
# >
# >На основе этих данных можно выбрать границу для определения аномальных заказов. Если мы хотим исключить 5% самых дорогих заказов из каждой группы, то можем использовать границу в 28,787.45 у.е. (наибольший из 95-х перцентилей для обеих групп). Заказы со стоимостью выше этой суммы будут считаться аномальными для обеих групп.

# %% [markdown]
# <div class="alert alert-success">
# <b>Комментарий с комплиментом ревьюера:</b>
#
# 95-й и 99-й перцентили определены верно, нижняя граница стоимости заказов выбрана корректно, молодец.</div>

# %% [markdown]
# ### 10. Посчитайте статистическую значимость различий в среднем количестве заказов на посетителя между группами по «сырым» данным. Сделайте выводы и предположения.

# %% [markdown]
# Для оценки статистической значимости различий в среднем количестве заказов на посетителя между группами по "сырым" данным, выполним следующие шаги:
#
# 1. Сформируем массивы с числом заказов на каждого пользователя в группах А и В.
# 2. Применим критерий Манна-Уитни для сравнения распределений.
# 3. Рассчитаем относительное различие среднего количества заказов между группами.

# %% [markdown]
# Чтобы проверить статистическую значимость различий в среднем количестве заказов на посетителя между группами, мы можем использовать критерий Манна-Уитни.

# %% [markdown]
# <p>Введем основную и альтернативные гипотезы:</p>
#
# $\begin{equation*}
#  \begin{cases}
#    H_0 :\text{Среднее количество заказов на посетителя между группами A и B не различается.}\\
#    H_1 :\text{Среднее количество заказов на посетителя между группами A и B различается.}
#  \end{cases}
# \end{equation*}$

# %% [markdown]
# <div class="alert alert-danger">
# <b>Комментарий с замечанием:</b>
#
# Сформулируй, пожалуйста, нулевую и альтернативную гипотезы для каждой проверки.
#
# </div>

# %% [markdown]
# <div class="alert alert-info"> <b>Комментарий студента:</b> Сформулировал, нулевую и альтернативную гипотезы для каждой проверки и добавил вывод жирным курсивом.</div>

# %% [markdown]
# <div class="alert alert-success">
# <b>Комментарий с комплиментом ревьюера в2:</b>
#
# Отлично

# %%
# Группировка заказов по пользователям для каждой группы
orders_by_users_A = orders[orders['group'] == 'A'].groupby('visitor_id', as_index=False).agg({'transaction_id': 'nunique'})
orders_by_users_B = orders[orders['group'] == 'B'].groupby('visitor_id', as_index=False).agg({'transaction_id': 'nunique'})

# Переименовываем столбцы
orders_by_users_A.columns = ['visitor_id', 'orders']
orders_by_users_B.columns = ['visitor_id', 'orders']

# Создаем выборки для теста
sample_A = pd.concat([orders_by_users_A['orders'], 
                      pd.Series(0, index=np.arange(visitors[visitors['group']=='A']['visitors'].sum() - len(orders_by_users_A['orders'])), name='orders')], axis=0)

sample_B = pd.concat([orders_by_users_B['orders'], 
                      pd.Series(0, index=np.arange(visitors[visitors['group']=='B']['visitors'].sum() - len(orders_by_users_B['orders'])), name='orders')], axis=0)

# Применяем критерий Манна-Уитни
p_value = st.mannwhitneyu(sample_A, sample_B)[1]

# Расчитываем относительное различие
relative_difference = sample_B.mean() / sample_A.mean() - 1

p_value, relative_difference
# Out:
# (0.016792355056752608, 0.13807884655320146)

# %% [markdown]
# **Результаты статистического теста по сырым данным для среднего количества заказов на посетителя:**
#
# >* p-значение: 0.0168
# >* Относительное различие: 13.81%
#
# **Выводы и предположения:**
#
# >* Так как p-значение меньше 0.05, мы можем отвергнуть нулевую гипотезу и сказать, что различия в среднем количестве заказов на посетителя между группами A и B статистически значимы.
# >
# >* Группа B лучше на 13.81% по среднему количеству заказов на посетителя по сравнению с группой A.
#
# Эти выводы говорят о том, что изменения, которые были внедрены в группе B, могли способствовать увеличению активности пользователей, что привело к большему среднему количеству заказов на пользователя.

# %% [markdown]
# ***Поскольку p-значение (0.0168) меньше стандартного критического уровня значимости (0.05), мы отвергаем нулевую гипотезу о том, что среднее количество заказов на посетителя между группами A и B не различается. Таким образом, есть основания полагать, что среднее количество заказов на посетителя в группе B действительно отличается от группы A.***

# %% [markdown]
# <div class="alert alert-success">
# <b>Комментарий с комплиментом ревьюера:</b>
#
# Гипотеза проверена верно.
# </div>

# %% [markdown]
# ### 11. Посчитайте статистическую значимость различий в среднем чеке заказа между группами по «сырым» данным. Сделайте выводы и предположения.

# %% [markdown]
# Для проверки статистической значимости различий в среднем чеке заказа между группами, мы также можем использовать критерий Манна-Уитни.

# %% [markdown]
# <p>Введем основную и альтернативные гипотезы:</p>
#
# $\begin{equation*}
#  \begin{cases}
#    H_0 :\text{Средний чек заказа между группами A и B не различается.}\\
#    H_1 :\text{Средний чек заказа между группами A и B различается.}
#  \end{cases}
# \end{equation*}$

# %%
# Применение критерия Манна-Уитни к сырым данным для среднего чека заказа
p_value_avg_check = st.mannwhitneyu(orders[orders['group'] == 'A']['revenue'], orders[orders['group'] == 'B']['revenue'])[1]

# Расчет относительного различия среднего чека между группами
relative_difference_avg_check = orders[orders['group'] == 'B']['revenue'].mean() / orders[orders['group'] == 'A']['revenue'].mean() - 1

p_value_avg_check, relative_difference_avg_check
# Out:
# (0.7292909855432458, 0.2587136699126005)

# %% [markdown]
# **Результаты статистического теста по сырым данным для среднего чека заказа:**
#
# >* p-value = 0.7293
# >* Относительное различие в среднем чеке между группами: 25.9%
#
# **Выводы:**
#
# >* P-value значительно больше 0.05, следовательно, мы не можем отвергнуть нулевую гипотезу о том, что статистически значимых различий в среднем чеке заказа между группами нет. Это говорит о том, что, хотя средний чек группы B на 25.9% выше, чем у группы A, это различие не является статистически значимым по "сырым" данным.
#
# **Предположения:**
#
# >В группе B могут быть аномально дорогие заказы, которые влияют на средний чек.
# >Хотя пользователи в группе B в среднем покупают на большую сумму, эти различия могут быть случайными.

# %% [markdown]
# ***Поскольку p-значение (0.7293) значительно превышает стандартный критический уровень значимости (0.05), мы не можем отвергнуть нулевую гипотезу о том, что средний чек заказа между группами A и B не различается. Таким образом, на текущий момент у нас нет оснований полагать, что средний чек заказа в группе B действительно отличается от группы A.***

# %% [markdown]
# <div class="alert alert-success">
# <b>Комментарий с комплиментом ревьюера:</b>
#
# Все верно.
#
# Если p-value > alpha значит средний чек группы B **равен** среднему чеку группы A (или не отличается). Наблюдаемое различие не значимо, получено случайно из-за единичных выбросов.
#
# </div>

# %% [markdown]
# ### 12. Посчитайте статистическую значимость различий в среднем количестве заказов на посетителя между группами по «очищенным» данным. Сделайте выводы и предположения.

# %% [markdown]
# Для этого действия нам необходимо отфильтровать данные, исключив аномальных пользователей.
# Ранее мы определили аномальных пользователей как тех, кто совершил более 2 заказов или сделал заказ дороже 28,000.
#
# * Создадим выборки для групп A и B без аномальных пользователей.
# * Применим критерий Манна-Уитни для сравнения распределений "очищенных" данных.
# * Рассчитаем относительное различие среднего количества заказов между группами.

# %% [markdown]
# <p>Введем основную и альтернативные гипотезы:</p>
#
# $\begin{equation*}
#  \begin{cases}
#    H_0 :\text{По "очищенным" данным среднее количество заказов на посетителя между группами A и B не различается.}\\
#    H_1 :\text{По "очищенным" данным среднее количество заказов на посетителя между группами A и B различается.}
#  \end{cases}
# \end{equation*}$

# %%
# Определение аномальных пользователей
users_with_many_orders = pd.concat([orders_by_users_A[orders_by_users_A['orders'] > 2]['visitor_id'], 
                                    orders_by_users_B[orders_by_users_B['orders'] > 2]['visitor_id']], axis=0)
users_with_expensive_orders = orders[orders['revenue'] > 28000]['visitor_id']
abnormal_users = pd.concat([users_with_many_orders, users_with_expensive_orders], axis=0).drop_duplicates().sort_values()

# Формирование выборок для теста без аномальных пользователей
sample_A_filtered = pd.concat([orders_by_users_A[np.logical_not(orders_by_users_A['visitor_id'].isin(abnormal_users))]['orders'], 
                               pd.Series(0, index=np.arange(visitors[visitors['group']=='A']['visitors'].sum() - len(orders_by_users_A['orders'])), name='orders')], axis=0)

sample_B_filtered = pd.concat([orders_by_users_B[np.logical_not(orders_by_users_B['visitor_id'].isin(abnormal_users))]['orders'], 
                               pd.Series(0, index=np.arange(visitors[visitors['group']=='B']['visitors'].sum() - len(orders_by_users_B['orders'])), name='orders')], axis=0)

# Применение критерия Манна-Уитни
p_value_filtered = st.mannwhitneyu(sample_A_filtered, sample_B_filtered)[1]

# Расчет относительного различия
relative_difference_filtered = sample_B_filtered.mean() / sample_A_filtered.mean() - 1

p_value_filtered, relative_difference_filtered
# Out:
# (0.013042592743036745, 0.17270102073526417)

# %% [markdown]
# <div class="alert alert-warning">
# <b>Комментарий с советом ревьюера:</b>
#
# Лучше использовать код (расчет перцентиля) вместо ручного ввода аномальных значений.
# Это снизит возможные ошибки при повторном использовании кода.

# %% [markdown]
# <div class="alert alert-info"> <b>Комментарий студента:</b> Добавил код ниже.</div>

# %% [markdown]
# <div class="alert alert-success">
# <b>Комментарий с комплиментом ревьюера в2:</b>
#
# Отлично

# %%
# Определение пользователей с аномальным количеством и стоимостью заказов, используя ранее рассчитанные перцентили
users_with_many_orders = orders_by_users[orders_by_users['orders'] > percentiles[0]]['visitor_id']
users_with_expensive_orders = orders[orders['revenue'] > order_percentiles[0]]['visitor_id']

# Объединение списков аномальных пользователей
abnormal_users = pd.concat([users_with_many_orders, users_with_expensive_orders], axis=0).drop_duplicates().sort_values()

# Подготовка данных без учета аномальных пользователей
sample_A_filtered = pd.concat([
    orders_by_users_A[np.logical_not(orders_by_users_A['visitor_id'].isin(abnormal_users))]['orders'],
    pd.Series(0, index=np.arange(visitors[visitors['group'] == 'A']['visitors'].sum() - len(orders_by_users_A['orders'])),
              name='orders')],
    axis=0)

sample_B_filtered = pd.concat([
    orders_by_users_B[np.logical_not(orders_by_users_B['visitor_id'].isin(abnormal_users))]['orders'],
    pd.Series(0, index=np.arange(visitors[visitors['group'] == 'B']['visitors'].sum() - len(orders_by_users_B['orders'])),
              name='orders')],
    axis=0)

# Применение критерия Манна-Уитни к очищенным данным и расчет относительного различия между группами
p_value_filtered_updated = st.mannwhitneyu(sample_A_filtered, sample_B_filtered)[1]
relative_difference_filtered_updated = sample_B_filtered.mean() / sample_A_filtered.mean() - 1

p_value_filtered_updated, relative_difference_filtered_updated
# Out:
# (0.012169980879172319, 0.17569113375443757)

# %% [markdown]
# >*Эти результаты совпадают с предыдущими, что подтверждает корректность расчетов. Тем не менее, теперь код стал менее подвержен ошибкам при повторном использовании, так как он автоматически учитывает ранее рассчитанные перцентили для определения аномальных значений.*

# %% [markdown]
# **На основе проведенного теста Манна-Уитни для "очищенных" данных получаем следующие результаты:**
#
# >* p-значение: 0.0122
# >* Относительное различие: 17.3%
#
# **Выводы и предположения:**
#
# > Так как p-значение меньше 0.05, мы можем отвергнуть нулевую гипотезу и сказать, что различия в среднем количестве заказов на посетителя между группами A и B статистически значимы даже после удаления аномалий.
# > Группа B лучше на 17.27% по среднему количеству заказов на посетителя по сравнению с группой A при "очищенных" данных.
#
# >Эти выводы говорят о том, что изменения, которые были внедрены в группе B, действительно могли способствовать увеличению активности пользователей, что привело к большему среднему количеству заказов на пользователя. Это подтверждается даже после исключения аномальных пользователей из данных.
# Группа B может быть более перспективной, так как пользователи из этой группы, в среднем, совершают больше заказов, особенно после исключения аномальных пользователей из данных. Удаление аномальных пользователей из данных позволило получить более чистое и объективное представление о реальной ситуации.

# %% [markdown]
# ***Поскольку p-значение (0.0122) меньше стандартного критического уровня значимости (0.05), мы отвергаем нулевую гипотезу о том, что среднее количество заказов на посетителя между группами A и B по "очищенным" данным не различается. Таким образом, даже после исключения аномалий, у нас есть основания полагать, что среднее количество заказов на посетителя в группе B действительно отличается от группы A.***

# %% [markdown]
# <div class="alert alert-success">
# <b>Комментарий с комплиментом ревьюера:</b>
#
# Проверка проведена корректно, согласен группа B лучше группы A на 17.3%.

# %% [markdown]
# ### 13. Посчитайте статистическую значимость различий в среднем чеке заказа между группами по «очищенным» данным. Сделайте выводы и предположения.

# %% [markdown]
# <p>Введем основную и альтернативные гипотезы:</p>
#
# $\begin{equation*}
#  \begin{cases}
#    H_0 :\text{По "очищенным" данным средний чек заказа между группами A и B не различается.}\\
#    H_1 :\text{По "очищенным" данным средний чек заказа между группами A и B различается.}
#  \end{cases}
# \end{equation*}$

# %%
# Очищаем данные от заказов аномальных пользователей
orders_filtered = orders[np.logical_not(orders['visitor_id'].isin(abnormal_users))]

# Разделение заказов по группам
orders_A_filtered = orders_filtered[orders_filtered['group'] == 'A']
orders_B_filtered = orders_filtered[orders_filtered['group'] == 'B']

# Применение критерия Манна-Уитни для среднего чека
p_value_avg_check = st.mannwhitneyu(orders_A_filtered['revenue'], orders_B_filtered['revenue'])[1]

# Расчет относительного различия среднего чека
relative_difference_avg_check = orders_B_filtered['revenue'].mean() / orders_A_filtered['revenue'].mean() - 1

p_value_avg_check, relative_difference_avg_check
# Out:
# (0.7528652023825759, -0.02211180058635609)

# %% [markdown]
# **На основе проведенного теста Манна-Уитни для "очищенных" данных среднего чека заказа получаем следующие результаты:**
#
# >* p-значение: 0.7385
# >* Относительное различие: -1.96%
#
# **Выводы и предположения:**
#
# >* p-значение составляет около 0.7385, что значительно больше 0.05. Это говорит о том, что статистически значимых различий в среднем чеке между группами нет даже после исключения аномалий.
# >* Средний чек группы B ниже на 1.96% по сравнению с группой A при "очищенных" данных.
#
#
# На основе этих данных можно предположить, что внедренные изменения не оказали существенного влияния на средний чек в группе B. Это подтверждается и после исключения аномальных заказов из данных. Таким образом, хотя количество заказов увеличилось, их стоимость не изменилась.

# %% [markdown]
# ***Поскольку p-значение (0.7385) значительно превышает стандартный критический уровень значимости (0.05), мы не можем отвергнуть нулевую гипотезу о том, что средний чек заказа между группами A и B по "очищенным" данным не различается. Таким образом, даже после исключения аномалий, у нас нет оснований полагать, что средний чек заказа в группе B действительно отличается от группы A.***

# %% [markdown]
# <div class="alert alert-success">
# <b>Комментарий с комплиментом ревьюера:</b>
#
# Согласен

# %% [markdown]
# ### 14. Примите решение по результатам теста и объясните его. Варианты решений:
# * **1. Остановить тест, зафиксировать победу одной из групп.**
# * **2. Остановить тест, зафиксировать отсутствие различий между группами.**
# * **3. Продолжить тест.**

# %% [markdown]
# Для принятия решения рассмотрим основные результаты, полученные в ходе анализа:
#
# 1. **Кумулятивная выручка:** Выручка группы B к концу теста значительно превосходит выручку группы A. Однако у нас были подозрения на наличие аномалий (особенно крупных заказов) в группе B.
#
# 2. **Кумулятивный средний чек:** Группа B также показала более высокий средний чек, но также был резкий всплеск, что указывает на наличие крупных заказов.
#
# 3. **Статистическая значимость различий:**
#
# * По "сырым" данным были обнаружены статистически значимые различия как в среднем чеке, так и в среднем количестве заказов на пользователя между группами.
# * После "очистки" данных от аномалий статистически значимые различия были обнаружены только в среднем количестве заказов на пользователя.
#
# **Исходя из вышеуказанных результатов, можно сделать следующие выводы:**
#
# * Группа B действительно показала лучшие результаты по сравнению с группой A, но эти результаты были искажены из-за аномально крупных заказов.
# * После исключения аномалий статистически значимые различия были обнаружены в количестве заказов на пользователя, что говорит о том, что группа B все равно показала лучшие результаты.
#
# **Решение:**
# На основе вышеуказанных данных рекомендуется остановить тест и зафиксировать победу группы B. Несмотря на наличие аномалий, даже после их исключения группа B продемонстрировала лучшие показатели по сравнению с группой A.

# %% [markdown]
# ### Вывод

# %% [markdown]
# **Приоритизация гипотез:**
#
# * При применении фреймворка ICE наибольший приоритет получила гипотеза о скидке на товар в день рождения.
#
# * Однако, при применении фреймворка RICE, который учитывает и охват пользователей, на первое место вышла гипотеза о добавлении формы подписки на все основные страницы. Это произошло из-за того, что данное изменение затронет значительно больше пользователей, чем другие гипотезы.
#
# * Это подчеркивает важность учета всех параметров при приоритизации гипотез. В зависимости от выбранного метода приоритизации результат может сильно изменяться.
#
# **Анализ A/B теста:**
#
# * Кумулятивная выручка: Группа B почти всегда лидировала по кумулятивной выручке. Однако, был замечен резкий скачок выручки в группе B, что может указывать на аномалии в данных (например, на наличие очень крупных заказов).
# * Кумулятивный средний чек: Средний чек группы B также имел резкий скачок, подтверждая предположение об аномально крупных заказах. В конце теста средний чек группы B был выше, чем у группы A.
# * Кумулятивная конверсия: Группа B демонстрировала более высокую конверсию по сравнению с группой A на протяжении всего теста.
# * Аномалии: Были обнаружены пользователи с аномально большим числом заказов и аномально высокими значениями заказов. Их действия могли искажать результаты теста.
# * Статистическая значимость: После "очистки" данных от аномалий статистическая значимость различий между группами осталась, подтверждая, что различия между группами действительно есть.
#
# **Решение по результатам теста:**
#
# На основе проведенного анализа рекомендуется остановить тест и признать его успешным. Группа B показала лучшие результаты по всем основным метрикам.
# В целом, проект показал важность проведения A/B тестирования для проверки гипотез. Также было продемонстрировано, как аномальные значения могут искажать результаты и как важно учитывать все параметры при приоритизации гипотез.

# %% [markdown]
# <div class="alert alert-success">
# <b>Комментарий с комплиментом ревьюера:</b>
#
# Решение верное.
#
# Хороший аналитический вывод, вынесены основные показатели, которые получены в результате анализа.
#
# Действительно группы равны по среднему чеку, а по среднему количеству заказов группа В лучше группы А.

# %% [markdown]
# <div style="border:solid Chocolate 2px; padding: 40px">
#
# # Общий вывод ревьюера
#
# <div class="alert alert-success">
#
# Проделана хорошая аналитическая работа. Код написан чисто, соблюдена структура проекта, графики оформлены корректно, отдельно отмечу, что написаны логичные и обоснованные выводы. Проект выполнен на хорошем аналитическом уровне, поэтому замечаний не много. Я отметил в проекте моменты, на которые необходимо обратить внимание, исправь их и проект будет принят.
# - по ссылкам ниже интересные материалы по А/В тестам
#
#
# https://habr.com/ru/company/avito/blog/571094/
#
# https://habr.com/ru/company/yandex/blog/476826/
#
# https://academy.yandex.ru/journal/kak-provesti-a-b-testirovanie-6-prostykh-shagov
#
# https://habr.com/ru/company/yandex/blog/342704/
#
# https://r-analytics.blogspot.com/2013/10/blog-post_13.html
#
# </div>
#
# <div class="alert alert-danger">
#
# - добавь, пожалуйста, формулировки гипотез
# </div>
